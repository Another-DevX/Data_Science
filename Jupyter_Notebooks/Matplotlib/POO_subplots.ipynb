# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots()
axes.plot(x,y)

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x, 'r')

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.plot(x,y)
ax2.plot(y,x, 'r')

# %%
fig, axes = plt.subplots(nrows=2,ncols=4)
axes[0,0].plot(x, np.cos(x))
axes[0,1].plot(x, np.sin(x), 'r')
axes[0,2].plot(x, np.tan(x), 'y')
axes[0,3].plot(x, np.cos(x)**2)
axes[1,0].plot(x, y * np.pi)
axes[1,1].plot(x, np.sqrt(x)**2)
axes[1,2].plot(x, y)
axes[1,3].plot(x, y / x)
fig.tight_layout()
# Out:
# /tmp/ipykernel_13209/3737982463.py:9: RuntimeWarning: invalid value encountered in divide
#   axes[1,3].plot(x, y / x)
