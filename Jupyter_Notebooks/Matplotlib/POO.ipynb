# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %% [markdown]
# ## Fig Axes
# axe = fig.add_axes([position x,position y, width, heigth])

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.5,0.9])
axes2 = fig.add_axes([0.15,0.55,0.2,0.4])
axes2.set_facecolor('gray')
axes.plot(x,y,'b')
axes2.plot(y,x,'r')
fig.show()
# Out:
# /tmp/ipykernel_12937/2047203057.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
